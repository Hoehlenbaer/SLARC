# %%
from tbparse import SummaryReader
import pandas as pd

log_dir = "/home/slarc/jupyter/logs"

# Lese das gesamte Log-Verzeichnis aus
reader = SummaryReader(log_dir)

# Wandle alle Daten in ein großes Pandas DataFrame um
df = reader.scalars

# Option A: Alles in EINE große CSV-Datei speichern
df.to_csv("alle_metriken_zusammen.csv", index=False)
